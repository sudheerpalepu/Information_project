# %%
import pandas as pd

# Load your CSV
data = pd.read_csv("jobs_data.csv")

# Check the first few rows
data.head()
# Out:
#                                            job_title  \
# 0                        Search Technology Developer
# 1                   Senior Agentic AI / RAG Engineer
# 2                         Java API + Kafka Developer
# 3                 Java Developer - Ukranian (Remote)
# 4  InDesign Developer / UI-UX & Graphic Design Pr...
#
#                                                  url posted_date  \
# 0  https://in.linkedin.com/jobs/view/search-techn...  2026-03-17
# 1  https://in.linkedin.com/jobs/view/senior-agent...  2026-03-17
# 2  https://www.naukri.com/job-listings-java-api-k...  2026-03-17
# 3  https://dk.linkedin.com/jobs/view/java-develop...  2026-03-17
# 4  http://in.indeed.com/job/indesign-developer-ui...  2026-03-17
#
#   job_country_code  is_remote employment_status  seniority  \
# 0               IN       True         full_time  mid_level
# 1               IN      False         full_time     senior
# 2               IN      False         full_time  mid_level
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2242 entries, 0 to 2241
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   job_title                    2242 non-null   object
#  1   url                          2242 non-null   object
#  2   posted_date                  2242 non-null   object
#  3   job_country_code             2242 non-null   object
#  4   is_remote                    2242 non-null   bool
#  5   employment_status            2214 non-null   object
#  6   seniority                    2242 non-null   object
#  7   job_location                 2242 non-null   object
#  8   job_description              2242 non-null   object
#  9   salary                       126 non-null    object
#  10  hiring_manager_full_name     150 non-null    object
#  11  hiring_manager_first_name    150 non-null    object
#  12  hiring_manager_role          69 non-null     object
# ...

# %%
data.describe()
# Out:
#        company_employee_count  company_revenue_usd
# count             2115.000000         2.930000e+02
# mean             14139.243026         2.307415e+10
# std              41773.479675         1.444613e+10
# min                  1.000000         3.100000e+05
# 25%                  5.000000         3.597500e+09
# 50%                  5.000000         3.250413e+10
# 75%                 54.000000         3.250413e+10
# max             141397.000000         3.250413e+10

# %%
import pandas as pd

# Load your CSV
data = pd.read_csv("naukari_jobs_data_lakhs.csv")

# Check the first few rows
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       3 # Load your CSV
# ----> 4 data = pd.read_csv("naukari_jobs_data_lakhs.csv")
#       6 # Check the first few rows
#       7 data.head()
#
# ...

# %%
data.shape
# Out:
# (2242, 23)
